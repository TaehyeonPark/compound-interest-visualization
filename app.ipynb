# %% [markdown]
# # Import modules

# %%
import cpi

# %% [markdown]
# # Main

# %% [markdown]
# ## Compound Interest Visualization

# %%
initial_value = 40000

# df1 = cpi.compound_growth(principal=initial_value, annual_rate=0.1,period_per_year=1, years=30)
df1 = cpi.compound_growth(principal=100000, annual_rate=0.1,period_per_year=2, years=30)
df2 = cpi.compound_growth(principal=40000, annual_rate=0.1,period_per_year=2, years=30)
# df3 = cpi.compound_growth(principal=15650, annual_rate=0.1,period_per_year=2, years=30)
df4 = cpi.compound_growth(principal=1000, annual_rate=0.1,period_per_year=2, years=30)
# df = deepcopy(df2)
# df['Asset Value'] -= df3["Asset Value"]

# cpi.plot([df2, df3])
cpi.plot([df1, df2, df4])
